# %% [markdown]
# # Python Algorithmic Trading Cookbook¶
#
# ## Chapter 2: Stock Markets: Primer on Trading

# %% [markdown]
# ### This Jupyter Notebook is created using Python version 3.7.2

# %% [markdown]
# ### Recipe 1: Setup Python connectivity with Broker

# %%
from kiteconnect import KiteConnect

# %%
# Get the api_key & api_secret from broker. These are unique to you & will be used by the broker to identify your demat account.
api_key = "<your-api-key>"
api_secret = "<your-api-secret>"

# %%
# Login to this URL with your broking account credentials & get the request token
kite = KiteConnect(api_key=api_key)
print(kite.login_url())
# Out:
# https://kite.trade/connect/login?api_key=5mrqgbb6ms4s73am&v=3

# %%
# Get the request token from the above URL
request_token = "<your-request-token>"

# %%
# Set the access token
data = kite.generate_session(request_token, api_secret=api_secret)
kite.set_access_token(data["access_token"])
kite

# %%
# If your connection is not setup correctly, you will get the following error when setting access token -

# data = kite.generate_session(request_token, api_secret=api_secret)
# kite.set_access_token(data["access_token"])
# kite
# Out:
# ---------------------------------------------------------------------------
# TokenException                            Traceback (most recent call last)
# <ipython-input-6-e46fddfcbedb> in <module>
#       1 # If your connection is not setup correctly, you will get the following error when setting access token -
#       2
# ----> 3 data = kite.generate_session(request_token, api_secret=api_secret)
#       4 kite.set_access_token(data["access_token"])
#       5 kite
#
# /usr/local/lib/python3.7/site-packages/kiteconnect-3.7.7-py3.7.egg/kiteconnect/connect.py in generate_session(self, request_token, api_secret)
#     230             "api_key": self.api_key,
#     231             "request_token": request_token,
# --> 232             "checksum": checksum
#     233         })
#     234
#
# /usr/local/lib/python3.7/site-packages/kiteconnect-3.7.7-py3.7.egg/kiteconnect/connect.py in _post(self, route, params)
#     699     def _post(self, route, params=None):
#     700         """Alias for sending a POST request."""
# --> 701         return self._request(route, "POST", params)
#     702
#     703     def _put(self, route, params=None):
#
# /usr/local/lib/python3.7/site-packages/kiteconnect-3.7.7-py3.7.egg/kiteconnect/connect.py in _request(self, route, method, parameters)
#     764                 # native Kite errors
#     765                 exp = getattr(ex, data["error_type"], ex.GeneralException)
# --> 766                 raise exp(data["message"], code=r.status_code)
#     767
#     768             return data["data"]
#
# TokenException: Token is invalid or has expired.

# %% [markdown]
# ### Recipe 2: Query list of Instruments

# %%
import pandas as pd

# %%
instruments = pd.DataFrame(kite.instruments())
instruments
# Out:
#        instrument_token exchange_token       tradingsymbol  \
# 0             245515780         959046         IFSL25OCT19
# 1             133410052         521133             GEMSPIN
# 2             128931588         503639             INDSOYA
# 3             245309188         958239         DHFL31AUG18
# 4             138695172         541778                DEEP
# 5             245526532         959088          EEL29NOV19
# 6             128015108         500059           BINANIIND
# 7             138716164         541860          D36MS244RG
# 8             138973444         542865             ANUROOP
# 9             132475140         517481                APTL
# 10            128354820         501386            ZSWASTSA
# 11            128927236         503622            ZSVTRADI
# 12            128927748         503624            ZSVARAJT
# 13            131146500         512291            ZSPEEDCO
# 14            130536964         509910            ZSOUTGAS
# 15            131165956         512367            ZSHERAPR
# 16            128996612         503893            ZSATYASL
# 17            129584644         506190            ZSARVAMA
# 18            131077124         512020            ZSARACOM
# 19            131087876         512062            ZSANMCOM
# 20            131337988         513039            ZHINUDYP
# 21            128729604         502850            ZGAEKWAR
# 22            136534788         533339              ZENTEC
# 23            129041156         504067          ZENSARTECH
# 24            136201988         532039            ZENOTECH
# 25            135858436         530697             ZENLABS
# 26            131213572         512553          ZENITHEXPO
# 27            131652100         514266             ZENIFIB
# 28            130278404         508900              ZENCAP
# 29            183680772         717503             ZEENCPS
# ...                 ...            ...                 ...
# 55498          15340546          59924    GRASIM20JAN860CE
# 55499          15340290          59923    GRASIM20JAN840PE
# 55500          15340034          59922    GRASIM20JAN840CE
# 55501          15339778          59921    GRASIM20JAN820PE
# 55502          15339522          59920    GRASIM20JAN820CE
# 55503          15339266          59919    GRASIM20JAN800PE
# 55504          15339010          59918    GRASIM20JAN800CE
# 55505          15338754          59917    GRASIM20JAN780PE
# 55506          15338498          59916    GRASIM20JAN780CE
# 55507          18783234          73372  GLENMARK19DEC410PE
# 55508          15045890          58773      GAIL20JAN120PE
# 55509            969473           3787               WIPRO
# 55510           4276481          16705               GOKUL
# 55511           4280065          16719             ALMONDZ
# 55512            860929           3363          SUPREMEIND
# 55513           1181953           4617       SUPREMEENG-SM
# 55514           2992385          11689            SUPRAJIT
# 55515            860161           3360            SUPPETRO
# 55516            611329           2388               NELCO
# 55517           2766849          10808       IDFCFIRSTB-N7
# 55518           2370561           9260          ARROWGREEN
# 55519           3726593          14557          AROGRANITE
# 55520           4419329          17263            ARMANFIN
# 55521           5164801          20175       ARIHANTSUP-BE
# 55522           3554561          13885             ARIHANT
# 55523           3892225          15204               ARIES
# 55524             46337            181            ARENTERP
# 55525            644865           2519         ARCOTECH-BE
# 55526           1638401           6400          ARCHIES-BE
# 55527           4299521          16795           ARCHIDPLY
#
#                                  name  last_price      expiry  strike  \
# 0                                             0.0                 0.0
# 1                  GEM SPINNERS INDIA         0.0                 0.0
# 2                             INDSOYA         0.0                 0.0
# 3                                             0.0                 0.0
# 4                                             0.0                 0.0
# 5                                             0.0                 0.0
# 6                                             0.0                 0.0
# 7                                             0.0                 0.0
# 8                                             0.0                 0.0
# 9                                             0.0                 0.0
# 10     SWASTIK SAFE DEPOSIT & INVESTM         0.0                 0.0
# 11             S.V.TRADING & AGENCIES         0.0                 0.0
# 12          SVARAJ TRADING & AGENCIES         0.0                 0.0
# 13               SPEEDAGE COMMERCIALS         0.0                 0.0
# 14                       SOUTHERN GAS         0.0                 0.0
# 15      SHERATON PROPERTIES & FINANCE         0.0                 0.0
# 16                  SATYAM SILK MILLS         0.0                 0.0
# 17     SARVAMANGAL MERCANTILE CO.LTD.         0.0                 0.0
# 18     SARASWATI COMMERCIAL (INDIA) L         0.0                 0.0
# 19                SANMITRA COMMERCIAL         0.0                 0.0
# 20                                            0.0                 0.0
# 21                                            0.0                 0.0
# 22                   ZEN TECHNOLOGIES         0.0                 0.0
# 23                ZENSAR TECHNOLOGIES         0.0                 0.0
# 24              ZENOTECH LABORATORIES         0.0                 0.0
# 25                     ZENLABS ETHICA         0.0                 0.0
# 26                     ZENITH EXPORTS         0.0                 0.0
# 27                      ZENITH FIBRES         0.0                 0.0
# 28                                            0.0                 0.0
# 29      ZEE ENTERTAINMENT ENTERPRISES         0.0                 0.0
# ...                               ...         ...         ...     ...
# 55498                                         0.0  2020-01-30   860.0
# 55499                                         0.0  2020-01-30   840.0
# 55500                                         0.0  2020-01-30   840.0
# 55501                                         0.0  2020-01-30   820.0
# 55502                                         0.0  2020-01-30   820.0
# 55503                                         0.0  2020-01-30   800.0
# 55504                                         0.0  2020-01-30   800.0
# 55505                                         0.0  2020-01-30   780.0
# 55506                                         0.0  2020-01-30   780.0
# 55507                                         0.0  2019-12-26   410.0
# 55508                                         0.0  2020-01-30   120.0
# 55509                           WIPRO         0.0                 0.0
# 55510                                         0.0                 0.0
# 55511                                         0.0                 0.0
# 55512              SUPREME INDUSTRIES         0.0                 0.0
# 55513                                         0.0                 0.0
# 55514            SUPRAJIT ENGINEERING         0.0                 0.0
# 55515       SUPREME PETROCHEMICALS LT         0.0                 0.0
# 55516                                         0.0                 0.0
# 55517                                         0.0                 0.0
# 55518                                         0.0                 0.0
# 55519                ARO GRANITE IND.         0.0                 0.0
# 55520                                         0.0                 0.0
# 55521                                         0.0                 0.0
# 55522                                         0.0                 0.0
# 55523                      ARIES AGRO         0.0                 0.0
# 55524                                         0.0                 0.0
# 55525                                         0.0                 0.0
# 55526                                         0.0                 0.0
# 55527                  ARCHIDPLY IND.         0.0                 0.0
#
#        tick_size  lot_size instrument_type  segment exchange
# 0           0.01         1              EQ      BSE      BSE
# 1           0.01       100              EQ      BSE      BSE
# 2           0.01        50              EQ      BSE      BSE
# 3           0.01         1              EQ      BSE      BSE
# 4           0.05      3000              EQ      BSE      BSE
# 5           0.01        10              EQ      BSE      BSE
# 6           0.01         1              EQ      BSE      BSE
# 7           0.01         1              EQ      BSE      BSE
# 8           0.01     10000              EQ      BSE      BSE
# 9           0.01         1              EQ      BSE      BSE
# 10          0.01         1              EQ      BSE      BSE
# 11          0.01         1              EQ      BSE      BSE
# 12          0.05         1              EQ      BSE      BSE
# 13          0.01        50              EQ      BSE      BSE
# 14          0.05         5              EQ      BSE      BSE
# 15          0.01       100              EQ      BSE      BSE
# 16          0.01        50              EQ      BSE      BSE
# 17          0.05         1              EQ      BSE      BSE
# 18          0.05         1              EQ      BSE      BSE
# 19          0.01         1              EQ      BSE      BSE
# 20          0.01         1              EQ      BSE      BSE
# 21          0.05         1              EQ      BSE      BSE
# 22          0.05         1              EQ      BSE      BSE
# 23          0.05         1              EQ      BSE      BSE
# 24          0.05         1              EQ      BSE      BSE
# 25          0.05         1              EQ      BSE      BSE
# 26          0.05         1              EQ      BSE      BSE
# 27          0.05         1              EQ      BSE      BSE
# 28          0.05         1              EQ      BSE      BSE
# 29          0.01         1              EQ      BSE      BSE
# ...          ...       ...             ...      ...      ...
# 55498       0.05       750              CE  NFO-OPT      NFO
# 55499       0.05       750              PE  NFO-OPT      NFO
# 55500       0.05       750              CE  NFO-OPT      NFO
# 55501       0.05       750              PE  NFO-OPT      NFO
# 55502       0.05       750              CE  NFO-OPT      NFO
# 55503       0.05       750              PE  NFO-OPT      NFO
# 55504       0.05       750              CE  NFO-OPT      NFO
# 55505       0.05       750              PE  NFO-OPT      NFO
# 55506       0.05       750              CE  NFO-OPT      NFO
# 55507       0.05      1000              PE  NFO-OPT      NFO
# 55508       0.05      5334              PE  NFO-OPT      NFO
# 55509       0.05         1              EQ      NSE      NSE
# 55510       0.05         1              EQ      NSE      NSE
# 55511       0.05         1              EQ      NSE      NSE
# 55512       0.05         1              EQ      NSE      NSE
# 55513       0.05      4000              EQ      NSE      NSE
# 55514       0.05         1              EQ      NSE      NSE
# 55515       0.05         1              EQ      NSE      NSE
# 55516       0.05         1              EQ      NSE      NSE
# 55517       0.01         1              EQ      NSE      NSE
# 55518       0.05         1              EQ      NSE      NSE
# 55519       0.05         1              EQ      NSE      NSE
# 55520       0.05         1              EQ      NSE      NSE
# 55521       0.05         1              EQ      NSE      NSE
# 55522       0.05         1              EQ      NSE      NSE
# 55523       0.05         1              EQ      NSE      NSE
# 55524       0.05       100              EQ      NSE      NSE
# 55525       0.05         1              EQ      NSE      NSE
# 55526       0.05         1              EQ      NSE      NSE
# 55527       0.05         1              EQ      NSE      NSE
#
# [55528 rows x 12 columns]

# %%
print(f'Total instruments: {len(instruments)}')
# Out:
# Total instruments: 55528

# %%
# Fetch an instrument for a specific tradingsymbol & exchange, for ex: TATASTEEL & NSE respectively.
instruments.loc[(instruments['tradingsymbol'] == 'TATASTEEL') & (instruments['exchange'] == 'NSE')]
# Out:
#        instrument_token exchange_token tradingsymbol        name  last_price  \
# 50910            895745           3499     TATASTEEL  TATA STEEL         0.0
#
#       expiry  strike  tick_size  lot_size instrument_type segment exchange
# 50910            0.0       0.05         1              EQ     NSE      NSE

# %% [markdown]
# ### Recipe 3: Query list of Exchanges

# %%
exchanges = instruments.exchange.unique()
print(exchanges)
# Out:
# ['BSE' 'CDS' 'NSE' 'MCX' 'NFO']

# %% [markdown]
# ### Recipe 4: Query list of Segments

# %%
segments = instruments.segment.unique()
print(segments)
# Out:
# ['BSE' 'CDS-FUT' 'CDS-OPT' 'INDICES' 'MCX' 'MCX-OPT' 'NFO-FUT' 'NFO-OPT'
#  'NSE']

# %% [markdown]
# ### Recipe 4: Variety Types, Product Types & Order Types

# %%
# Varieties offered by Broker
print('\'Variety\' for orders offered by Broker...')
print('- ' + KiteConnect.VARIETY_REGULAR)
print('- ' + KiteConnect.VARIETY_BO)
print('- ' + KiteConnect.VARIETY_CO)
print('- ' + KiteConnect.VARIETY_AMO)
# Out:
# 'Variety' for orders offered by Broker...
# - regular
# - bo
# - co
# - amo

# %%
# Product Types offered by Broker
print('\'Product\' for orders offered by Broker...\n')
print('- ' + KiteConnect.PRODUCT_BO + '\t(Order supports Stoploss & Target price)')
print('- ' + KiteConnect.PRODUCT_CO + '\t(Order supports Stoploss & Target price)')
print('- ' + KiteConnect.PRODUCT_CNC)
print('- ' + KiteConnect.PRODUCT_MIS)
print('- ' + KiteConnect.PRODUCT_NRML)
# Out:
# 'Product' for orders offered by Broker...
#
# - BO	(Order supports Stoploss & Target price)
# - CO	(Order supports Stoploss & Target price)
# - CNC
# - MIS
# - NRML

# %%
# Order Types offered by Broker
print('\'Order Types\' offered by Broker...\n')
print('- ' + KiteConnect.ORDER_TYPE_MARKET + '\t(Order will be placed at Market price)')
print('- ' + KiteConnect.ORDER_TYPE_LIMIT + '\t\t(Order will be placed at specified price)')
print('- ' + KiteConnect.ORDER_TYPE_SLM + '\t\t(Order will be placed at Market price with a Stoploss)')
print('- ' + KiteConnect.ORDER_TYPE_SL + '\t\t(Order will be placed at specified price with a Stoploss)')
# Out:
# 'Order Types' offered by Broker...
#
# - MARKET	(Order will be placed at Market price)
# - LIMIT		(Order will be placed at specified price)
# - SL-M		(Order will be placed at Market price with a Stoploss)
# - SL		(Order will be placed at specified price with a Stoploss)

# %% [markdown]
# ### Recipe 6: Place REGULAR & BRACKET orders

# %%
# Place a REGULAR variety BUY order with Product=MIS, Order Type=MARKET
order_id = kite.place_order(variety=KiteConnect.VARIETY_REGULAR, exchange=KiteConnect.EXCHANGE_NSE, 
                            tradingsymbol='TATASTEEL', transaction_type=KiteConnect.TRANSACTION_TYPE_BUY, 
                            quantity=1, product=KiteConnect.PRODUCT_MIS, order_type=KiteConnect.ORDER_TYPE_MARKET,
                            price='402')
print(order_id)

# Check you broker site & you will see an order placed with these parameters
# Out:
# 191209000001676

# %%
# Place a BRACKET variety BUY order with Product=MIS, Order Type=LIMIT
order_id = kite.place_order(variety=KiteConnect.VARIETY_BO, exchange=KiteConnect.EXCHANGE_NSE, 
                            tradingsymbol='ICICIBANK', transaction_type=KiteConnect.TRANSACTION_TYPE_SELL, 
                            quantity=1, product=KiteConnect.PRODUCT_MIS, order_type=KiteConnect.ORDER_TYPE_LIMIT,
                            price='525', squareoff=10, stoploss=10)
print(order_id)

# Check you broker site & you will see an order placed with these parameters
# Out:
# 191209000001677

# %% [markdown]
# ### Recipe 7: Place INTRADAY & DELIVERY orders

# %%
# Place an DELIVERY REGULAR variety SELL order with Order Type=LIMIT
order_id = kite.place_order(variety=KiteConnect.VARIETY_REGULAR, exchange=KiteConnect.EXCHANGE_NSE, 
                            tradingsymbol='AXISBANK', transaction_type=KiteConnect.TRANSACTION_TYPE_SELL, 
                            quantity=1, product=KiteConnect.PRODUCT_CNC, order_type=KiteConnect.ORDER_TYPE_MARKET,
                            price='718')
print(order_id)

# Check you broker site & you will see an order placed with these parameters
# Out:
# 191209000001678

# %%
# Place a INTRADAY BRACKET variety BUY order with Order Type=LIMIT
order_id = kite.place_order(variety=KiteConnect.VARIETY_BO, exchange=KiteConnect.EXCHANGE_NSE, 
                            tradingsymbol='HDFCBANK', transaction_type=KiteConnect.TRANSACTION_TYPE_SELL, 
                            quantity=1, product=KiteConnect.PRODUCT_MIS, order_type=KiteConnect.ORDER_TYPE_LIMIT,
                            price='1245', squareoff=10, stoploss=10)
print(order_id)

# Check you broker site & you will see an order placed with these parameters
# Out:
# 191209000001680

# %% [markdown]
# ### Recipe 8: Query Credit Exposure & Margins given by Broker

# %%
# Query the margins
margins = kite.margins()

# %%
# Equity segment margins
equity_margins = margins['equity']
equity_margins
# Out:
# {'enabled': True,
#  'net': 2064.56,
#  'available': {'adhoc_margin': 0,
#   'cash': 2064.56,
#   'opening_balance': 2064.56,
#   'live_balance': 2064.56,
#   'collateral': 0,
#   'intraday_payin': 0},
#  'utilised': {'debits': 0,
#   'exposure': 0,
#   'm2m_realised': 0,
#   'm2m_unrealised': 0,
#   'option_premium': 0,
#   'payout': 0,
#   'span': 0,
#   'holding_sales': 0,
#   'turnover': 0,
#   'liquid_collateral': 0,
#   'stock_collateral': 0}}

# %%
equity_margins['net']
# Out:
# 2064.56

# %%
equity_margins['utilised']['exposure']
# Out:
# 0

# %%
# Commodity segment margins
commodity_margins = margins['commodity']
commodity_margins
# Out:
# {'enabled': True,
#  'net': 0,
#  'available': {'adhoc_margin': 0,
#   'cash': 0,
#   'opening_balance': 0,
#   'live_balance': 0,
#   'collateral': 0,
#   'intraday_payin': 0},
#  'utilised': {'debits': 0,
#   'exposure': 0,
#   'm2m_realised': 0,
#   'm2m_unrealised': 0,
#   'option_premium': 0,
#   'payout': 0,
#   'span': 0,
#   'holding_sales': 0,
#   'turnover': 0,
#   'liquid_collateral': 0,
#   'stock_collateral': 0}}

# %%
commodity_margins['net']
# Out:
# 0

# %%
commodity_margins['utilised']['exposure']
# Out:
# 0
